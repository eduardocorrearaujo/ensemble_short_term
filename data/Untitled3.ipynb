# %%
import pandas as pd

# %%
df = pd.read_csv('dengue_up.csv.gz')

df.head()
# Out:
#    Unnamed: 0        date  year  epiweek  casos  geocode  \
# 0           0  2010-01-03  2010   201001      0  4208450
# 1           1  2010-01-03  2010   201001      0  4216206
# 2           2  2010-01-03  2010   201001      0  4218509
# 3           3  2010-01-03  2010   201001      0  4216404
# 4           4  2010-01-03  2010   201001      0  4201307
#
#                   regional  regional_geocode                   macroregional  \
# 0                 Nordeste             42011       Planalto Norte e Nordeste
# 1                 Nordeste             42011       Planalto Norte e Nordeste
# 2               Meio Oeste             42008  Meio Oeste e Serra Catarinense
# 3  Extremo Sul Catarinense             42014                             Sul
# 4                 Nordeste             42011       Planalto Norte e Nordeste
#
#    macroregional_geocode  uf
# 0                   4211  SC
# 1                   4211  SC
# 2                   4212  SC
# 3                   4210  SC
# ...

# %%
df.date.min()
# Out:
# '2010-01-03'

# %%
df.date.max()
# Out:
# '2024-08-04'
